# %%
import pandas as pd

df = pd.read_csv("https://data.heatonresearch.com/data/t81-558/iris.csv")

# %%
df
# Out:
#      sepal_l  sepal_w  petal_l  petal_w         species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 3        4.6      3.1      1.5      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      2.5      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import csv
import urllib.request
import codecs
import numpy as np

url = "https://data.heatonresearch.com/data/t81-558/iris.csv"
urlstream = urllib.request.urlopen(url)
csvfile = csv.reader(codecs.iterdecode(urlstream, 'utf-8'))
next(csvfile) # Skip header row
sum = np.zeros(4)
count = 0

for line in csvfile:
    # Convert each row to Numpy array
    line2 = np.array(line)[0:4].astype(float)
    
    # If the line is of the right length (skip empty lines), then add
    if len(line2) == 4:
        sum += line2
        count += 1
        
# Calculate the average, and print the average of the 4 iris 
# measurements (features)
print(sum/count)
# Out:
# [5.84333333 3.05733333 3.758      1.19933333]

# %%
# My solution

import numpy as np
import pandas as pd
import requests
import io
import statistics as st
import math


url="https://data.heatonresearch.com/data/t81-558/datasets/reg-33-data.csv"
s=requests.get(url).content
data =pd.read_csv(io.StringIO(s.decode('utf-8')))

type(data) # data is a dataframe

# Add a column named ratio (max/number). Leave max and number in the dataframe.

for i in range(0,len(data['max'])):
    data['ratio'] = data['max']/data['number']
    

# Finding nan values and changing these values by the median of the column


# median = st.median(data['length']) # I take the median before introducing any value.

# o = [x for x in range(0,10809)]

# for i,x in list(zip(o,data.length)):
#    if math.isnan(x) == True:
#                 data.length[i] = float(median)
# Out:
# 2.6940428340032394
# 5.643897364771151
# 1.7642730381335758
# 1.9002828054298642
# 1.2366589327146171
# 3.3015153660954537
# 1.8668426322016929
# 1.3488132943934845
# 2.7769032258064517
# 3.745857574195449
# 2.4044572843582337
# 3.1619093307747663
# 2.0468988362463496
# 1.6201217038539555
# 1.5841596430342093
# 1.9227634660421546
# 2.9907087496498272
# 3.242581404052826
# 1.9311112347671249
# 5.13049672333555
# 2.5333748866727106
# 3.177255284156667
# 3.1292652687186675
# 2.5960943712998144
# 2.71726335115287
# 1.976625367224422
# 5.357768790023593
# 3.19488485129036
# 3.9127960345144115
# 2.5489256007393717
# 4.298345153664303
# 3.235558408215661
# 3.038735841141099
# 2.3040418916707575
# 1.7796141982413334
# 1.4355938597254867
# 2.4296976067270375
# 2.4099261339356572
# 2.6344805942044145
# 3.2631027253668763
# 3.924542682926829
# 2.5575439172549665
# 5.223400331919602
# 2.0464809315042665
# 1.4768127081732
# 2.3455699292165
# 2.3249882714206507
# 2.278542808455764
# ...

# %%
# Out:
# 15071.6955
